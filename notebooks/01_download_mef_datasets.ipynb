# %%
from pathlib import Path
import sys

def find_repo_root(start: Path) -> Path:
    for candidate in [start, *start.parents]:
        if (candidate / "scripts" / "download_mef_datasets.py").exists():
            return candidate
    raise FileNotFoundError("Could not locate repo root with scripts/download_mef_datasets.py")

repo_root = find_repo_root(Path.cwd().resolve())
scripts_dir = repo_root / "scripts"
if str(scripts_dir) not in sys.path:
    sys.path.insert(0, str(scripts_dir))

from download_mef_datasets import download_all

results = download_all()
results
# Out:
# [{'dataset': 'Detalle de inversiones',
#   'slug': 'detalle-de-inversiones',
#   'source': 'https://datosabiertos.mef.gob.pe/dataset/detalle-de-inversiones',
#   'downloaded_at': '2026-05-01T20:45:37.627137+00:00',
#   'used_fallback': True,
#   'resources': {'csv': {'name': 'data',
#     'url': 'https://fs.datosabiertos.mef.gob.pe/datastorefiles/DETALLE_INVERSIONES.csv',
#     'format': 'csv'},
#    'dictionary': {'name': 'dictionary',
#     'url': 'https://fs.datosabiertos.mef.gob.pe/datastorefiles/Detalle_Inversiones_Diccionario.csv',
#     'format': 'csv'}},
#   'files': {'csv': 'data/raw/detalle-de-inversiones/data.csv',
#    'dictionary': 'data/raw/detalle-de-inversiones/dictionary.csv'}},
#  {'dataset': 'Formato 12B de inversiones',
#   'slug': 'formato-12b-de-de-inversiones',
#   'source': 'https://datosabiertos.mef.gob.pe/dataset/formato-12b-de-de-inversiones',
#   'downloaded_at': '2026-05-01T20:46:02.549019+00:00',
#   'used_fallback': True,
#   'resources': {'csv': {'name': 'data',
#     'url': 'https://fs.datosabiertos.mef.gob.pe/datastorefiles/FORMATO_12B.csv',
#     'format': 'csv'},
#    'dictionary': {'name': 'dictionary',
#     'url': 'https://fs.datosabiertos.mef.gob.pe/datastorefiles/F12B_Diccionario.csv',
#     'format': 'csv'}},
#   'files': {'csv': 'data/raw/formato-12b-de-de-inversiones/data.csv',
#    'dictionary': 'data/raw/formato-12b-de-de-inversiones/dictionary.csv'}},
#  {'dataset': 'Estado situacional de inversiones',
#   'slug': 'estado-situacional-de-inversiones',
#   'source': 'https://datosabiertos.mef.gob.pe/dataset/estado-situacional-de-inversiones',
#   'downloaded_at': '2026-05-01T20:46:36.093745+00:00',
#   'used_fallback': True,
#   'resources': {'csv': {'name': 'data',
#     'url': 'https://fs.datosabiertos.mef.gob.pe/datastorefiles/ESTADO_SITUACIONAL.csv',
#     'format': 'csv'},
#    'dictionary': {'name': 'dictionary',
#     'url': 'https://fs.datosabiertos.mef.gob.pe/datastorefiles/Estado_Situacional_Diccionario.csv',
#     'format': 'csv'}},
#   'files': {'csv': 'data/raw/estado-situacional-de-inversiones/data.csv',
#    'dictionary': 'data/raw/estado-situacional-de-inversiones/dictionary.csv'}},
#  {'dataset': 'Componentes de las inversiones',
#   'slug': 'proceso-de-seleccion-de-inversiones',
#   'source': 'https://datosabiertos.mef.gob.pe/dataset/proceso-de-seleccion-de-inversiones',
#   'downloaded_at': '2026-05-01T20:49:20.776038+00:00',
#   'used_fallback': True,
#   'resources': {'csv': {'name': 'data',
#     'url': 'https://fs.datosabiertos.mef.gob.pe/datastorefiles/PROCESO_SELECCION.csv',
#     'format': 'csv'},
#    'dictionary': {'name': 'dictionary',
#     'url': 'https://fs.datosabiertos.mef.gob.pe/datastorefiles/Proceso_Selecccion_Diccionario.csv',
#     'format': 'csv'}},
#   'files': {'csv': 'data/raw/proceso-de-seleccion-de-inversiones/data.csv',
#    'dictionary': 'data/raw/proceso-de-seleccion-de-inversiones/dictionary.csv'}},
#  {'dataset': 'Cierre de inversiones',
#   'slug': 'cierre-de-inversiones',
#   'source': 'https://datosabiertos.mef.gob.pe/dataset/cierre-de-inversiones',
#   'downloaded_at': '2026-05-01T20:49:34.914051+00:00',
#   'used_fallback': True,
#   'resources': {'csv': {'name': 'data',
#     'url': 'https://fs.datosabiertos.mef.gob.pe/datastorefiles/CIERRE_INVERSIONES.csv',
#     'format': 'csv'},
#    'dictionary': {'name': 'dictionary',
#     'url': 'https://fs.datosabiertos.mef.gob.pe/datastorefiles/Cierre_Inversiones_Diccionario.csv',
#     'format': 'csv'}},
#   'files': {'csv': 'data/raw/cierre-de-inversiones/data.csv',
#    'dictionary': 'data/raw/cierre-de-inversiones/dictionary.csv'}}]
